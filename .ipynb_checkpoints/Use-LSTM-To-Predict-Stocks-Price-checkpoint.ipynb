# %%
import pandas_datareader.data as web
import datetime

# %%
start =datetime.datetime(2000,1,1)
end = datetime.datetime(2023,9,30)

# %%
# Get data
df = web.DataReader('GOOGL','stooq',start,end)
df.sort_index(inplace=True)
df
# Out:
#                  Open      High        Low      Close       Volume
# Date
# 2004-08-19    2.50000    2.6015    2.39900    2.50850  894076000.0
# 2004-08-20    2.52525    2.7270    2.51250    2.70775  457144000.0
# 2004-08-23    2.76875    2.8370    2.72625    2.73500  365488000.0
# 2004-08-24    2.78100    2.7900    2.58925    2.62175  305252000.0
# 2004-08-25    2.62400    2.7000    2.59700    2.65000  183956000.0
# ...               ...       ...        ...        ...          ...
# 2023-09-25  129.83000  131.1700  128.96000  131.11000   20094643.0
# 2023-09-26  129.77000  130.3645  127.22000  128.56500   25718704.0
# 2023-09-27  128.57000  130.8950  128.57000  130.54000   22746452.0
# 2023-09-28  129.84000  133.3000  129.79000  132.31000   22513132.0
# 2023-09-29  133.28000  134.0500  130.36000  130.86000   30859790.0
#
# [4812 rows x 5 columns]

# %%
# predict in 10 days
pre_days =10
df['label'] = df['Close'].shift(-pre_days)
df
# Out:
#                  Open      High        Low      Close       Volume    label
# Date
# 2004-08-19    2.50000    2.6015    2.39900    2.50850  894076000.0  2.53775
# 2004-08-20    2.52525    2.7270    2.51250    2.70775  457144000.0  2.50025
# 2004-08-23    2.76875    2.8370    2.72625    2.73500  365488000.0  2.53950
# 2004-08-24    2.78100    2.7900    2.58925    2.62175  305252000.0  2.55750
# 2004-08-25    2.62400    2.7000    2.59700    2.65000  183956000.0  2.55775
# ...               ...       ...        ...        ...          ...      ...
# 2023-09-25  129.83000  131.1700  128.96000  131.11000   20094643.0      NaN
# 2023-09-26  129.77000  130.3645  127.22000  128.56500   25718704.0      NaN
# 2023-09-27  128.57000  130.8950  128.57000  130.54000   22746452.0      NaN
# 2023-09-28  129.84000  133.3000  129.79000  132.31000   22513132.0      NaN
# 2023-09-29  133.28000  134.0500  130.36000  130.86000   30859790.0      NaN
#
# [4812 rows x 6 columns]

# %%
# data standardization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
sca_X = scaler.fit_transform(df.iloc[:,:-1])
sca_X
# Out:
# array([[-1.02093162, -1.01807023, -1.02337784, -1.02053077,  5.14743076],
#        [-1.02025664, -1.01475318, -1.02031023, -1.01520651,  2.23843076],
#        [-1.01374747, -1.0118458 , -1.01453313, -1.01447835,  1.62820468],
#        ...,
#        [ 2.34913509,  2.37281965,  2.38669244,  2.40066284, -0.6536954 ],
#        [ 2.38308437,  2.43638554,  2.41966583,  2.44795989, -0.65524879],
#        [ 2.47504145,  2.45620858,  2.43507143,  2.40921372, -0.59967853]])

# %%
# memory days
mem_his_days = 5

# %%
# building featutres

from collections import deque
deq = deque(maxlen=mem_his_days)

X = []
for i in sca_X:
    deq.append(list(i))
    if len(deq)==mem_his_days:
        X.append(list(deq))
        
X_lately = X[-pre_days:]
X=X[:-pre_days]
print(len(X))
print(len(X_lately))

y = df['label'].values[mem_his_days-1:-pre_days]
print(len(y))
# Out:
# 4798
# 10
# 4798

# %%
import numpy as np

# %%
X = np.array(X)
y = np.array(y)

# %%
# Build LSTM
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [37], in <cell line: 2>()
#       1 # Build LSTM
# ----> 2 import tensorflow as tf
#       3 from tensorflow.keras.models import Sequential
#       4 from tensorflow.keras.layers import LSTM, Dense, Dropout
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.14.0-cp39-cp39-win_amd64.whl (2.1 kB)
# Collecting tensorflow-intel==2.14.0
#   Downloading tensorflow_intel-2.14.0-cp39-cp39-win_amd64.whl (284.1 MB)
# Collecting flatbuffers>=23.5.26
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.5.4-py3-none-any.whl (19 kB)
# Collecting tensorflow-estimator<2.15,>=2.14.0
#   Downloading tensorflow_estimator-2.14.0-py2.py3-none-any.whl (440 kB)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.12.1)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting keras<2.15,>=2.14.0
#   Downloading keras-2.14.0-py3-none-any.whl (1.7 MB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.42.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.1.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.24.4)
# Collecting tensorboard<2.15,>=2.14
#   Downloading tensorboard-2.14.1-py3-none-any.whl (5.5 MB)
# Requirement already satisfied: setuptools in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (61.2.0)
# Collecting ml-dtypes==0.2.0
#   Downloading ml_dtypes-0.2.0-cp39-cp39-win_amd64.whl (938 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Requirement already satisfied: h5py>=2.9.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.6.0)
# Requirement already satisfied: packaging in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (21.3)
# Requirement already satisfied: absl-py>=1.0.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.2.0)
# Collecting numpy>=1.23.5
#   Downloading numpy-1.26.1-cp39-cp39-win_amd64.whl (15.8 MB)
# Requirement already satisfied: six>=1.12.0 in d:\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.16.0)
# Collecting libclang>=13.0.0
#   Downloading libclang-16.0.6-py2.py3-none-win_amd64.whl (24.4 MB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.14.0->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.23.3)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.2.3)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.59.0-cp39-cp39-win_amd64.whl (3.7 MB)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.28.1)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.3.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.4.8)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.1.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.14.0->tensorflow) (3.0.4)
# Installing collected packages: tensorboard-data-server, numpy, grpcio, google-auth-oauthlib, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, ml-dtypes, libclang, keras, google-pasta, gast, flatbuffers, astunparse, tensorflow-intel, tensorflow
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.6.1
#     Uninstalling tensorboard-data-server-0.6.1:
#       Successfully uninstalled tensorboard-data-server-0.6.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] 拒绝访问。: 'D:\\anaconda3\\Lib\\site-packages\\~umpy\\core\\_multiarray_tests.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
